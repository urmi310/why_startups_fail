# %% [markdown]
# # 📉 Why Startups Fail – Data Analysis Project
# This project explores why startups fail using real-world style data. We analyze patterns based on funding, burn rate, revenue, and more.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a9d8f85-d309-4179-913f-7eb5d11fb7ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a9d8f85-d309-4179-913f-7eb5d11fb7ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('startup_failure_prediction.csv')
df.head()
# Out:
#   Startup_Name    Industry  Startup_Age  Funding_Amount  Number_of_Founders  \
# 0    Startup_1   Logistics            8        18328419                   2
# 1    Startup_2   Education            3        39753708                   3
# 2    Startup_3  Healthcare           14        18073294                   1
# 3    Startup_4  E-commerce            5        19435653                   4
# 4    Startup_5     Finance           14         4205797                   4
#
#    Founder_Experience  Employees_Count   Revenue  Burn_Rate Market_Size  \
# 0                  13              581  97866143     602731      Medium
# 1                  16              529  36868744     820698       Large
# 2                  28               82   3478737     992205       Small
# 3                  14              234  80716899     536747      Medium
# 4                  17              960  53347246     555199      Medium
#
#   Business_Model  Product_Uniqueness_Score  Customer_Retention_Rate  \
# ...

# %%
df['Startup_Status'] = df['Startup_Status'].astype(str).str.strip()
df['Startup_Status'].unique()
# Out:
# array(['1'], dtype=object)

# %%
df['Startup_Status'] = df['Startup_Status'].astype(int)

# %%
df_failed = df[df['Startup_Status'] == 1]
df_failed.shape
# Out:
# (5000, 15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

industry_counts = df_failed['Industry'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=industry_counts.values, y=industry_counts.index, palette='Oranges_r')
plt.title('Top 10 Industries Where Startups Failed')
plt.xlabel('Number of Failed Startups')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1452045269.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=industry_counts.values, y=industry_counts.index, palette='Oranges_r')

# %%
# Plot: Funding vs. Startup Status
plt.figure(figsize=(8,6))
sns.boxplot(x='Startup_Status', y='Funding_Amount', data=df)
plt.title('Funding Amount by Startup Status (0=Operating, 1=Failed)')
plt.xlabel('Startup Status')
plt.ylabel('Funding Amount')
plt.tight_layout()
plt.show()

# %%
# Plot: Burn Rate vs. Startup Status
plt.figure(figsize=(8,6))
sns.boxplot(x='Startup_Status', y='Burn_Rate', data=df)
plt.title('Burn Rate by Startup Status')
plt.xlabel('Startup Status')
plt.ylabel('Burn Rate')
plt.tight_layout()
plt.show()

# %%
# Plot: Customer Retention Rate vs. Startup Status
plt.figure(figsize=(8,6))
sns.boxplot(x='Startup_Status', y='Customer_Retention_Rate', data=df)
plt.title('Customer Retention by Startup Status')
plt.xlabel('Startup Status')
plt.ylabel('Retention Rate (%)')
plt.tight_layout()
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# ✅ Conclusion
# - Most failed startups are in a few industries.
# - Higher burn rate & lower retention often lead to failure.
# - Funding alone doesn't guarantee success.
# - Market size and uniqueness may play important roles.
